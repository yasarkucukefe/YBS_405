# %% [markdown]
# ## Ölçeklendirme ve Normalizasyon
#
# ### Bir veri setindeki sayısal değerleri modellemede yardımcı olması amacıyla dönüştürmek gerekir.

# %%
import pandas as pd
import numpy as np
from scipy import stats
from mlxtend.preprocessing import minmax_scaling
import seaborn as sns
import matplotlib.pyplot as plt

# %%
veri = np.random.exponential(size=1000)

# %%
print(veri)
# Out:
# [1.45050102e-01 6.47464566e-01 2.36261124e-01 2.37529803e+00
#  4.45762083e-01 3.12238731e+00 2.79586277e-01 1.26527504e+00
#  1.05216283e-01 2.16572800e+00 4.99720459e-01 1.00357051e+00
#  2.39832105e+00 2.30545237e+00 1.77292605e-01 1.02693019e-01
#  1.59455333e+00 3.00922804e+00 3.93227688e-01 5.04237328e-01
#  1.42548601e+00 2.95198151e-01 1.21825675e-01 3.71596553e-01
#  5.12937229e-01 5.17293338e-01 9.91399712e-01 4.06972588e+00
#  5.84147251e-01 1.54617654e+00 6.67603550e-01 1.10638025e+00
#  2.52157363e+00 9.68033267e-02 1.11401203e+00 7.97703169e-01
#  5.19488705e-01 5.52110183e-01 1.11359285e+00 4.91950269e-01
#  4.64810779e-01 1.13098765e+00 4.39134596e-01 4.13188844e-01
#  4.62808854e-01 3.74518678e+00 2.41729330e+00 1.60218350e+00
#  2.46200860e-02 3.21602161e-01 1.60618939e+00 1.45991559e+00
#  1.82409645e+00 1.13593982e+00 1.47357978e+00 6.17946943e-01
#  8.96523014e-01 1.46917945e+00 2.16947208e+00 5.53311899e-01
# ...

# %%
sns.displot(veri)

# %%
olcekli_veri = minmax_scaling(veri, columns=[0])

# %%
sns.displot(olcekli_veri)

# %%
olcekli_veri.max()
# Out:
# 1.0

# %% [markdown]
# ## Normalizasyon

# %%
normalize_veri = stats.boxcox(veri)

# %%
sns.displot(normalize_veri)

# %%
# https://tr.linkedin.com/pulse/veri-bilimi-notlar%C4%B1-4-%C3%B6zellik-%C3%B6l%C3%A7eklendirme-abdullah-faruk-%C3%A7i%CC%87ftler

# %%
# Iris data seti
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
 
dataset = load_iris()
 
# Splitting the independent and dependent variables
i_data = dataset.data
response = dataset.target
 
# standardization 
scaled = StandardScaler().fit_transform(i_data) 
print(scaled)
# Out:
# [[-9.00681170e-01  1.01900435e+00 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00 -1.31979479e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.38535265e+00  3.28414053e-01 -1.39706395e+00 -1.31544430e+00]
#  [-1.50652052e+00  9.82172869e-02 -1.28338910e+00 -1.31544430e+00]
#  [-1.02184904e+00  1.24920112e+00 -1.34022653e+00 -1.31544430e+00]
#  [-5.37177559e-01  1.93979142e+00 -1.16971425e+00 -1.05217993e+00]
#  [-1.50652052e+00  7.88807586e-01 -1.34022653e+00 -1.18381211e+00]
#  [-1.02184904e+00  7.88807586e-01 -1.28338910e+00 -1.31544430e+00]
#  [-1.74885626e+00 -3.62176246e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00  9.82172869e-02 -1.28338910e+00 -1.44707648e+00]
#  [-5.37177559e-01  1.47939788e+00 -1.28338910e+00 -1.31544430e+00]
#  [-1.26418478e+00  7.88807586e-01 -1.22655167e+00 -1.31544430e+00]
#  [-1.26418478e+00 -1.31979479e-01 -1.34022653e+00 -1.44707648e+00]
#  [-1.87002413e+00 -1.31979479e-01 -1.51073881e+00 -1.44707648e+00]
# ...

# %%
sns.displot(scaled[:,1])

# %% [markdown]
# ## Tarihleri okumak

# %%
df = pd.DataFrame({'sene':[2021, 2022], 'ay':[5, 9], 'gun':[12, 25]})

# %%
print(df)
# Out:
#    sene  ay  gun
# 0  2021   5   12
# 1  2022   9   25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sene    2 non-null      int64
#  1   ay      2 non-null      int64
#  2   gun     2 non-null      int64
# dtypes: int64(3)
# memory usage: 176.0 bytes

# %%
df.columns = ['year','month','day']
pd.to_datetime(df) # datetime nesnesine dönüştür
# Out:
# 0   2021-05-12
# 1   2022-09-25
# dtype: datetime64[ns]

# %%
df.head()
# Out:
#    year  month  day
# 0  2021      5   12
# 1  2022      9   35

# %%
# Saniye
df = pd.DataFrame({'unix_saniye':[1669098627,1669098628], 'sicaklik':[24, 25]})

# %%
df.head()
# Out:
#    unix_saniye  sicaklik
# 0   1669098627        24
# 1   1669098628        25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix_saniye  2 non-null      int64
#  1   sicaklik     2 non-null      int64
# dtypes: int64(2)
# memory usage: 160.0 bytes

# %%
df['zaman_dt'] = pd.to_datetime(df.unix_saniye, unit='s')

# %%
df.head()
# Out:
#    unix_saniye  sicaklik            zaman_dt
# 0   1669098627        24 2022-11-22 06:30:27
# 1   1669098628        25 2022-11-22 06:30:28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix_saniye  2 non-null      int64
#  1   sicaklik     2 non-null      int64
#  2   zaman_dt     2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 176.0 bytes

# %%
# Zaman etiketli
df = pd.DataFrame({'zaman':['2021-11-08 13:12:03','2021-11-08 13:12:04'], 'sicaklik':[24, 25]})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zaman     2 non-null      object
#  1   sicaklik  2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
df['zaman'] = pd.to_datetime(df.zaman)

# %%
df.head()
# Out:
#                 zaman  sicaklik
# 0 2021-11-08 13:12:03        24
# 1 2021-11-08 13:12:04        25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zaman     2 non-null      datetime64[ns]
#  1   sicaklik  2 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 160.0 bytes

# %%
df.zaman.dt.weekday # haftanın kaçıncı günü olduğunu bulmak için
# Out:
# 0    0
# 1    0
# Name: zaman, dtype: int64

# %%
# 0 : Monday (Pazartesi)

# %% [markdown]
# ## Veri tutarlılığı

# %%
df = pd.DataFrame({'ulkeler':['Almanya','almanya','İngiltere','ingiltere','Türkiye',' Türkiye'],'veri':[2,4,6,3,8,8]})

# %%
print(df)
# Out:
#      ulkeler  veri
# 0    Almanya     2
# 1    almanya     4
# 2  İngiltere     6
# 3  ingiltere     3
# 4    Türkiye     8
# 5    Türkiye     8

# %%
df.ulkeler.unique()
# Out:
# array(['Almanya', 'almanya', 'İngiltere', 'ingiltere', 'Türkiye',
#        ' Türkiye'], dtype=object)

# %%
df.groupby(['ulkeler']).sum()
# Out:
#            veri
# ulkeler
#  Türkiye      8
# Almanya       2
# Türkiye       8
# almanya       4
# ingiltere     3
# İngiltere     6

# %%
# fuzzywuzzy kütüphanesi ile string'lerin benzerlikleri test edilebilir

# %%
# !pip install fuzzywuzzy 
# !pip install python-Levenshtein

# %%
import fuzzywuzzy

# %%
fuzzywuzzy.fuzz.ratio("this is a test", "this is a test!")
# Out:
# 97

# %%
fuzzywuzzy.fuzz.ratio("Türkiye", " Türkiye")
# Out:
# 93

# %%
def bir_kolondaki_benzerleri_bul(df, kolon, string_to_match, min_ratio=47):
    benzerler = fuzzywuzzy.process.extract(string_to_match,
                                       df.ulkeler, limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    cok_benzerler = [benzer[0] for benzer in benzerler if benzer[1] >= min_ratio]
    benzer_satirlar = df[kolon].isin(cok_benzerler)
    df.loc[benzer_satirlar, kolon] = string_to_match
    print(f"{string_to_match} değiştirildi")

# %%
bir_kolondaki_benzerleri_bul(df, kolon='ulkeler', string_to_match='İngiltere')
# Out:
# İngiltere değiştirildi

# %%
df
# Out:
#      ulkeler  veri
# 0    Almanya     2
# 1    almanya     4
# 2  İngiltere     6
# 3  İngiltere     3
# 4    Türkiye     8
# 5    Türkiye     8

# %%
bir_kolondaki_benzerleri_bul(df, kolon='ulkeler', string_to_match='Türkiye')
# Out:
# Türkiye değiştirildi

# %%
df.ulkeler.unique()
# Out:
# array(['Almanya', 'almanya', 'İngiltere', 'Türkiye'], dtype=object)

# %%
bir_kolondaki_benzerleri_bul(df, kolon='ulkeler', string_to_match='Almanya')
# Out:
# Almanya değiştirildi

# %%
df.ulkeler.unique()
# Out:
# array(['Almanya', 'İngiltere', 'Türkiye'], dtype=object)

# %%
df.groupby(['ulkeler']).sum()
# Out:
#            veri
# ulkeler
# Almanya       6
# Türkiye      16
# İngiltere     9

# %% [markdown]
# ## Titanic veriseti

# %%
# Veriseti
data = pd.read_csv("https://raw.githubusercontent.com/yasarkucukefe/YBS_405/2021/data/titanic.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  892 non-null    int64
#  1   Survived     892 non-null    int64
#  2   Pclass       892 non-null    int64
#  3   Name         892 non-null    object
#  4   Sex          892 non-null    object
#  5   Age          715 non-null    float64
#  6   SibSp        892 non-null    int64
#  7   Parch        892 non-null    int64
#  8   Ticket       892 non-null    object
#  9   Fare         892 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     890 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.8+ KB

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['Survived'].value_counts()
# Out:
# 0    550
# 1    342
# Name: Survived, dtype: int64

# %%
data['Survived'].value_counts().plot.pie()
# Out:
# <AxesSubplot: ylabel='Survived'>

# %%
data.groupby(['Pclass','Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           373
#         1           119
# Name: Survived, dtype: int64

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           469
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
# Out:
# <AxesSubplot: xlabel='Sex'>

# %%
pd.crosstab(data.Pclass, data.Survived)
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         373  119

# %%
pd.crosstab(data.Sex, data.Survived)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      469  109

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# C:\Users\yasar\AppData\Local\Temp\ipykernel_16124\1119197534.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <AxesSubplot: >

# %%
data.shape # Dataframe'in satır ve kolon sayısını gösterir
# Out:
# (892, 12)
